# %%
import numpy as np
import pandas as pd

from math import e
import matplotlib.pyplot as plt

np.random.seed(42)

print('라이브러리 import 완료')
# Out:
# 라이브러리 import 완료

# %%
data = {
    'temperature': [10, 15, 20, 25, 30, 35],
    'humidity'   : [30, 40, 50, 60, 70, 80],
    'y'          : [0, 0, 1, 1, 1, 0]
}

df = pd.DataFrame(data)

df
# Out:
#    temperature  humidity  y
# 0           10        30  0
# 1           15        40  0
# 2           20        50  1
# 3           25        60  1
# 4           30        70  1
# 5           35        80  0

# %%
# 그림(figure) 하나를 만듭니다.
plt.figure(figsize=(7, 5))

# y=0인 점과 y=1인 점을 나누어 서로 다른 marker로 그립니다.
# boolean indexing: df["y"] == 0인 행만 골라냅니다.
mask0 = df['y'] == 0  # y가 0인 행(쾌적하지 않음)
mask1 = df['y'] == 1  # y가 1인 행(쾌적함)

# y=0 그룹: marker='o' (동그라미)
plt.scatter(df.loc[mask0, 'temperature'], df.loc[mask0, 'humidity'],
            marker='o', s=120, label='y = 0')

# y=1 그룹: marker='^' (삼각형)
plt.scatter(df.loc[mask1, 'temperature'], df.loc[mask1, 'humidity'],
            marker='^', s=120, label='y = 1')

# 각 점 옆에 y값을 작게 표시합니다.
# zip으로 (온도, 습도, y)를 한 줄씩 꺼내면서 텍스트를 붙입니다.
for temp, hum, yv in zip(df['temperature'], df['humidity'], df['y']):
    plt.annotate(f'y={yv}', (temp, hum),
                 textcoords='offset points', xytext=(6, 6), fontsize=9)
    
# 축 라벨, 제목, 범례, 격자 설정
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('Temperature-Humidity Comfort Data')
plt.legend()
plt.grid(True)

plt.show()

# %%
# X_raw: 원본 입력값. 온도와 습도를 나란히 붙여 (행의 수, 2) 모양으로 만듭니다.
#        shape = (n, 2) -> 열 0 = 온도, 열 1 = 습도
X_raw = df[['temperature', 'humidity']].to_numpy(dtype=float)

# y: 실제 정답. (n, 1) 모양의 세로 벡터로 만듭니다.

# reshape(-1, 1)의 의미를 자세히 봅니다.
#   - 첫 번째 값 -1 : '행 개수는 자동으로 맞춰라'라는 뜻입니다.
#                    (전체 개수를 보고 NumPy가 알아서 행 수를 계산합니다.)
#   - 두 번째 값  1 : '열은 1개로 만들어라'라는 뜻입니다.
# 즉 reshape(-1, 1)은 값들을 (n, 1) 모양의 '세로 벡터'로 세우라는 뜻입니다.
# 이렇게 y, z, H를 모두 (n, 1) 모양으로 맞추면, 곱셈/뺄셈 계산이 어긋나지 않고 안전합니다.
y = df['y'].to_numpy(dtype=float).reshape(-1, 1)

# %%
# X_mean: 각 입력 컬럼(온도, 습도)의 평균.
#         axis=0은 '열 방향으로 계산' = 컬럼별 평균 이라는 뜻입니다.
#         keepdims=True 로 (1, 2) 모양을 유지해 브로드캐스팅이 쉽게 되도록 합니다.
X_mean = X_raw.mean(axis=0, keepdims=True)    # shape = (1, 2)

# X_std: 각 입력 컬럼의 표준편차.
X_std = X_raw.std(axis=0, keepdims=True)      # shape = (1, 2)

# X_norm: 정규화된 입력값. (원본 - 평균) / 표준편차
#          X_raw는 (n, 2), X_mean/X_std는 (1, 2)이지만
#          NumPy 브로드캐스팅 덕분에 컬럼별로 자동 계산됩니다.

# [정규화를 왜, 어디에 쓰는지 정리]
#   - 학습(Gradient Descent)에는 정규화된 값 X_norm을 사용합니다.
#     -> 온도(10~38)와 습도(30~80)처럼 범위가 다른 값을 그대로 넣으면 학습이 불안정하기 때문입니다.
#   - 반대로 그래프와 결과 해석에는 원래 온도, 습도 단위(X_raw)를 사용합니다.
#     -> 사람은 '온도 25도, 습도 55%'처럼 원래 단위가 훨씬 이해하기 쉽기 때문입니다.
#   즉, 컴퓨터 학습에는 정규화된 값이 안정적이고,
#       사람 해석에는 원래 단위가 편하므로, 둘을 목적에 맞게 나누어 씁니다.
X_norm = (X_raw - X_mean) / X_std             # shape = (n, 2)

# %%
# 확인용으로 평균과 표준편차를 출력합니다.
print('X_mean (온도평균, 습도평균):', X_mean)
print('X_std  (온도표준편차, 습도표준편차):', X_std)
print('X_norm shape:', X_norm.shape)
print('y shape:', y.shape)
# Out:
# X_mean (온도평균, 습도평균): [[22.5 55. ]]
# X_std  (온도표준편차, 습도표준편차): [[ 8.53912564 17.07825128]]
# X_norm shape: (6, 2)
# y shape: (6, 1)

# %%
# 정규화된 값을 DataFrame 에 새 컬럼으로 추가해 원본과 함께 봅니다.
# 여기서는 표에 보기 좋게 넣기만 할 것이므로 (n,) 1차원 형태인 X_norm[:, 0]을 사용합니다.
# (학습 코드에서는 y와 모양을 맞추려고 (n, 1)형태인 X_norm[:, [0]]를 사용합니다. 뒤에서 다시 설명합니다.)
# 참고: (n,)와 (n, 1)은 모양이 다르며, 브로드캐스팅 방식이 달라져 계산 결과가 달라질 수 있으므로 목적에 맞게 구분해서 씁니다.
df['temperature_norm'] = X_norm[:, 0]
df['humidity_norm'] = X_norm[:, 1]

df
# Out:
#    temperature  humidity  y  temperature_norm  humidity_norm
# 0           10        30  0          -1.46385       -1.46385
# 1           15        40  0          -0.87831       -0.87831
# 2           20        50  1          -0.29277       -0.29277
# 3           25        60  1           0.29277        0.29277
# 4           30        70  1           0.87831        0.87831
# 5           35        80  0           1.46385        1.46385

# %%
def sigmoid(H):
    # H는 sigmoid 이전의 선형 출력값입니다. (확률이 아님)
    # H가 아주 크거나 아주 작으면 exp 계산에서 overflow(값이 너무 커짐)가 날 수 있습니다.
    # 그래서 H를 -500 ~ 500 사이로 잘라(clip) 계산을 안정적으로 만듭니다.
    H_clip = np.clip(H, -500, 500)
    
    # sigmoid 공식: 1 / (1 + e^(-H))
    # 반환값 z는 항상 0과 1 사이의 예측확률입니다.
    z = 1.0 / (1.0 + e ** (-H_clip))
    return z

# 동작을 확인합니다.
# H=0이면 z=0.5, H가 크면 z는 1에 가까워지고, H가 작으면 z는 0에 가까워집니다.
print('sigmoid(0)   =', sigmoid(np.array(0.0)))
print('sigmoid(10)  =', sigmoid(np.array(10.0)))
print('sigmoid(-10) =', sigmoid(np.array(-10.0)))
# Out:
# sigmoid(0)   = 0.5
# sigmoid(10)  = 0.9999546021312976
# sigmoid(-10) = 4.539786870243442e-05

# %%
def bce_cost(y, z):
    # y: 실제 정답(0 또는 1), z: 예측확률 (0~1)
    # epsilon: log(0)을 피하기 위한 아주 작은 값
    #   - log(0)은 무한대가 되어 Cost 계산이 불안정해집니다.
    #   - epsilon은 수학적 의미를 바꾸는 값이 아니라, 계산 안정성을 위한 값입니다.
    epsilon = 1e-7
    
    # z를 [epsilon, 1-epsilon] 범위로 잘라 log 계산을 안정적으로 만듭니다.
    z_clip = np.clip(z, epsilon, 1.0-epsilon)
    
    # BCE 공식: -[y*log(z) + (1-y)*log(1-z)]
    # 각 데이터마다 cost 값이 나오므로, 평균(mean)을 내어 하나의 cost로 만듭니다.
    cost = -(y * np.log(z_clip) + (1.0-y) * np.log(1.0-z_clip))
    
    # 반환값은 전체 데이터에 대한 '평균 Cost'입니다.
    return np.mean(cost)

# 동작 확인: 정답과 예측이 비슷하면 Cost가 작고, 반대면 큽니다.
y_test = np.array([[1.0], [0.0]])
z_good = np.array([[0.9], [0.1]])
z_bad = np.array([[1.0], [0.9]])
print('잘 맞힌 경우의 Cost:', bce_cost(y_test, z_good))
print('크게 틀린 경우의 Cost:', bce_cost(y_test, z_bad))
# Out:
# 잘 맞힌 경우의 Cost: 0.10536051565782628
# 크게 틀린 경우의 Cost: 1.1512925964970255

# %%
# 정규화된 입력에서 온도 열과 습도 열을 각각 (n, 1) 세로 벡터로 꺼냅니다.

# [주의] X_norm[:, 0]과 X_norm[:, [0]]은 모양(shape)이 다릅니다.
#   - X_norm[:, 0]   -> shape가 (n,)  인 1차원 배열 (가로로 늘어선 값)
#   - X_norm[:, [0]] -> shape가 (n, 1)인 2차원 세로 벡터 (열이 1개)
# 이번 노트북에서는 y가 (n, 1) 모양이므로, 계산할 때 모양을 맞추기 위해
# 대괄호를 한 번 더 쓴 X_norm[:, [0]] (즉 (n, 1) 세로 벡터)를 사용합니다.
X1_norm = X_norm[:, [0]]   # 정규화된 온도, shape = (n, 1)
X2_norm = X_norm[:, [1]]   # 정규화된 습도, shape = (n, 1)

# %%
# 학습할 파라미터의 초기값. 모두 0에서 시작합니다.
a1 = 0.0   # 온도 가중치
a2 = 0.0   # 습도 가중치
b = 0.0    # 편향(bias)

# 학습 설정
learning_rate = 0.1
epochs = 10000

# 학습 과정의 Cost를 저장할 리스트 (나중에 그래프로 그립니다.)
cost_history = []

# %%
# ---- 학습 반복 시작 ----
# for epoch in range(epochs)는 '같은 데이터를 여러 번 (=epochs 번) 반복하면서
# 파라미터(a1, a2, b)를 조금씩 수정해 나가는 과정입니다.
for epoch in range(epochs):
    # 1) 순전파: 선형 출력 H 계산 (H는 확률이 아님)
    H = a1 * X1_norm + a2 * X2_norm + b     # shape = (n, 1)
    
    # 2) sigmoid 로 예측확률 z 계산 (z 는 0~1)
    z = sigmoid(H)                          # shape = (n, 1)
    
    # 3) Cost 계산 (평균 BCE)
    cost = bce_cost(y, z)
    cost_history.append(cost)
    
    # 4) gradient 계산
    #    BCE Cost와 sigmoid를 함께 미분하면 dCost/dH = (z - y)가 됩니다.
    #    이 값은 '지난 강의의 error = y - pred'와는 다른, Cost를 미분해서 나온 
    #    gradient 신호이므로 이름을 grad_signal로 부릅니다. (자세한 설명은 위 마크다운 참고)
    #    각 가중치의 gradient는 grad_signal에 해당 입력을 곱해 평균을 냅니다.
    grad_signal = z - y                    # '예측확률 - 실제값' (Cost 미분에서 나온 gradient 신호)
    grad_a1 = np.mean(grad_signal * X1_norm)
    grad_a2 = np.mean(grad_signal * X2_norm)
    grad_b = np.mean(grad_signal)
    
    # 5) 파라미터 업데이트: 값 = 값 - learning_rate * gradient
    #    (gradient는 Cost가 증가하는 방향이므로 '빼서' Cost를 줄입니다.)
    a1 = a1 - learning_rate * grad_a1
    a2 = a2 - learning_rate * grad_a2
    b = b - learning_rate * grad_b
    
    # 1000 epoch마다 진행 상황을 출력합니다.
    if epoch % 100 == 0:
        print(f'epoch {epoch:5d} | cost={cost:.6f} | a1={a1:.4f} | b={b:.4f}')
# Out:
# epoch     0 | cost=0.693147 | a1=0.0146 | b=0.0000
# epoch   100 | cost=0.649174 | a1=0.3052 | b=0.0000
# epoch   200 | cost=0.649169 | a1=0.3085 | b=0.0000
# epoch   300 | cost=0.649169 | a1=0.3085 | b=0.0000
# epoch   400 | cost=0.649169 | a1=0.3085 | b=0.0000
# epoch   500 | cost=0.649169 | a1=0.3085 | b=0.0000
# epoch   600 | cost=0.649169 | a1=0.3085 | b=0.0000
# epoch   700 | cost=0.649169 | a1=0.3085 | b=0.0000
# epoch   800 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch   900 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1000 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1100 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1200 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1300 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1400 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1500 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1600 | cost=0.649169 | a1=0.3085 | b=-0.0000
# epoch  1700 | cost=0.649169 | a1=0.3085 | b=-0.0000
# ...

# %%
# 마지막 상태도 한 번 출력합니다.
print('-' * 60)
print(f'학습 종료 | 최종 cost={cost_history[-1]:.6f}')
print(f'학습된 파라미터: a1={a1:.4f}, a2={a2:.4f}, b={b:.4f}')
# Out:
# ------------------------------------------------------------
# 학습 종료 | 최종 cost=0.649169
# 학습된 파라미터: a1=0.3085, a2=0.3085, b=-0.0000

# %%
# cost_history에는 학습 반복(epoch)마다 계산된 Cost가 순서대로 저장되어 있습니다.
plt.figure(figsize=(7, 5))

# x축: epoch 번호(0, 1, 2, ...) / y축: 그 때의 Cost
# Cost가 내려간다는 것은 예측확률 z가 실제 정답 y에 맞게 조정되고 있다는 뜻입니다.
# 다만 Cost가 내려가도 단일 퍼셉트론이 '직선 하나'만 만든다는 구조적 한계는 사라지지 않습니다.
# (이 데이터는 가운데 구간만 1이라, 직선 하나로 완전히 분리하기 어렵습니다.)
plt.plot(range(len(cost_history)), cost_history)

plt.xlabel('Epoch')
plt.ylabel('Cost')
plt.title('Single Perceptron Cost')
plt.grid(True)

plt.show()

# %%
# 학습이 끝난 파라미터(a1, a2, b)로 최종 순전파를 다시 계산합니다.
H_final = a1 * X1_norm + a2 * X2_norm + b      # 학습이 끝난 뒤의 선형 출력값 (확률 아님)
z_final = sigmoid(H_final)                     # 학습이 끝난 뒤의 예측확률 (0~1)

# 예측확률 z가 0.5 이상이면 1, 아니면 0으로 판정합니다.
#   - (z_final >= 0.5)는 각 값마다 True/False를 만듭니다.
#   - .astype(int)는 True/False를 1/0으로 바꿔 예측 클래스로 만듭니다.
pred = (z_final >= 0.5).astype(int)

# 결과를 표(DataFrame)로 정리합니다.
#   - ravel()은 (n, 1) 세로 벡터를 표에 넣기 좋게 (n,) 1차원으로 펼치는 역할입니다.
result_df = pd.DataFrame({
    'temperature': df['temperature'].to_numpy(),
    'humidity': df['humidity'].to_numpy(),
    'y_actual': y.astype(int).ravel(),                # 실제 정답
    'H': np.round(H_final.ravel(), 4),                # 선형 출력값 (소수 4자리)
    'z_probability': np.round(z_final.ravel(), 4),    # 예측확률 (소수 4자리)
    'single_perceptron_pred': pred.ravel(),           # 예측 클래스(0/1)
})

# is_correct: 실제 정답(y_actual)과 예측 결과(single_perceptron_pred)가 같은지 확인하는 열입니다. (같으면 True)
result_df['is_correct'] = result_df['y_actual'] == result_df['single_perceptron_pred']

# 전체 결과 표를 출력합니다.
result_df
# Out:
#    temperature  humidity  y_actual       H  z_probability  \
# 0           10        30         0 -0.9033         0.2884
# 1           15        40         0 -0.5420         0.3677
# 2           20        50         1 -0.1807         0.4550
# 3           25        60         1  0.1807         0.5450
# 4           30        70         1  0.5420         0.6323
# 5           35        80         0  0.9033         0.7116
#
#    single_perceptron_pred  is_correct
# 0                       0        True
# 1                       0        True
# 2                       0       False
# 3                       1        True
# 4                       1        True
# 5                       1       False

# %%
# 오답 행만 따로 골라냅니다. (is_correct가 False인 행)
wrong_df = result_df[result_df['is_correct'] == False]

# 오답 개수를 셉니다.
n_wrong = len(wrong_df)

if n_wrong > 0:
    # 오답이 있으면 오답 개수와 오답 행을 함께 출력합니다.
    print(f'단일 퍼셉트론이 틀린 데이터: 총 {n_wrong}개')
    print('-' * 60)
    display(wrong_df)
    
    # 오답 행을 자동으로 해석하는 문장을 만들어 출력합니다.
    # (어떤 구간을 틀리는지는 학습 결과에 따라 달라질 수 있으므로, 실제 오답 구간을 그대로 읽어 줍니다.)
    wrong_temps = wrong_df['temperature'].tolist()   # 오답이 난 온도 값들
    print('-' * 60)
    print(f'[자동 해석] 오답이 발생한 구간(온도 기준): {wrong_temps}')
    print('이 구간을 틀리는 이유는 \'학습을 덜 해서\' 가 아니라,')
    print('단일 퍼셉트론이 만들 수 있는 판단 경계가 \'H = 0 직선 하나\'뿐이기 때문입니다.')
    print('직선 하나로는 가운데(1)를 양쪽(0)에서 동시에 떼어낼 수 없어, 위 구간에서 오답이 생깁니다.')
else:
    # 오답이 없어도, 결정 경계는 여전히 직선 하나임을 강조합니다.
    print('[자동 해석] 이번 설정에서는 모든 데이터를 맞혔습니다.')
    print('하지만 결정 경계는 여전히 \'H = 0 직선 하나\'라는 한계가 그대로 남아 있습니다.')
    print('모든 데이터를 맞혔다고 해서 구조적 한계가 사라진 것은 아니며,')
    print('이 한계는 아래 결정 경계 시각화에서 다시 확인합니다.')
# Out:
# 단일 퍼셉트론이 틀린 데이터: 총 2개
# ------------------------------------------------------------
#    temperature  humidity  y_actual       H  z_probability  \
# 2           20        50         1 -0.1807         0.4550
# 5           35        80         0  0.9033         0.7116
#
#    single_perceptron_pred  is_correct
# 2                       0       False
# 5                       1       False
# ------------------------------------------------------------
# [자동 해석] 오답이 발생한 구간(온도 기준): [20, 35]
# 이 구간을 틀리는 이유는 '학습을 덜 해서' 가 아니라,
# 단일 퍼셉트론이 만들 수 있는 판단 경계가 'H = 0 직선 하나'뿐이기 때문입니다.
# 직선 하나로는 가운데(1)를 양쪽(0)에서 동시에 떼어낼 수 없어, 위 구간에서 오답이 생깁니다.

# %%
# 단일 퍼셉트론의 예측 결과를 원본 온도, 습도 그래프 위에 표시합니다.

# 이 그래프의 목적은 "결정 경계 공식을 직접 계산하는 것"이 아닙니다.
# 목적은 단일 퍼셉트론이 어떤 데이터를 맞히고, 어떤 데이터를 틀렸는지
# 눈으로 확인하는 것입니다.

# 단일 퍼셉트론은 결국 직선 하나를 기준으로 0과 1을 나눕니다.
# 그런데 이 데이터는 가운데 구간만 1이고, 양쪽 구간은 0인 구조입니다.
# 따라서 직선 하나로는 모든 점을 자연스럽게 나누기 어렵습니다.

# %%
# 실제 정답 기준으로 데이터를 나눕니다.
# mask0: y가 0인 데이터
# mask1: y가 1인 데이터
mask0 = df['y'] == 0
mask1 = df['y'] == 1

# %%
# 단일 퍼셉트론의 예측 결과를 그래프로 확인합니다.
# 동그라미(o): 실제 정답 y = 0
# 세모(^): 실제 정답 y = 1
# 큰 빨간 원: 예측이 틀린 데이터
plt.figure(figsize=(7, 5))

# 실제 정답이 0인 데이터 표시
plt.scatter(
    df.loc[mask0, 'temperature'], df.loc[mask0, 'humidity'],
    marker='o', s=120, label='y = 0'
)
# 실제 정답이 1인 데이터 표시
plt.scatter(
    df.loc[mask1, 'temperature'], df.loc[mask1, 'humidity'],
    marker='^', s=120, label='y = 1'
)
# 예측이 틀린 데이터만 선택합니다.
wrong_df = result_df[result_df['is_correct'] == False]
# 틀린 데이터가 있으면 큰 빨간 원으로 강조합니다.
if len(wrong_df) > 0:
    plt.scatter(
        wrong_df['temperature'], wrong_df['humidity'],
        s=400, facecolors='none', edgecolors='red',
        linewidths=2, label='wrong'
    )
# 그래프 제목과 축 이름을 설정합니다.
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.title('Single Preceptron Prediction Result')

# 범례와 격자를 표시합니다.
plt.legend()
plt.grid(True)

plt.show()
