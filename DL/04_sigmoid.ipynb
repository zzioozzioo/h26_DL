# %%
# math는 파이썬에서 수학적인 계산을 할 수 있도록 도와주는 라이브러리입니다.
# 여기에서 자연상수 e를 가져옵니다. e는 약 2.71828 값을 가지는 수학적으로 중요한 상수입니다.
from math import e

# %%
# 시그모이드(sigmoid) 함수 설명:
# 시그모이드 함수의 수식은 다음과 같습니다:
# sigmoid(H(x)) = 1 / (1 + e^(-H(x)))
# 시그모이드 함수는 인공지능에서 입력값을 받아서 0과 1 사이의 값을 출력하는 함수로,
# 입력값을 확률(0~1 사이의 값)로 바꿔주는 데 자주 사용됩니다.

# %%
# 예시 1: 선형 회귀 결과 (H(x))가 -5일 때 시그모이드 값을 계산합니다.

sigmoid_minus_5 = 1 / (1 + e**-(-5))

sigmoid_minus_5
# Out:
# 0.006692850924284857

# %%
# 예시 2: 선형 회귀 결과 (H(x))가 -2.5일 때 시그모이드 값을 계산합니다.

sigmoid_minus_2_5 = 1 / (1 + e**-(-2.5))

sigmoid_minus_2_5
# Out:
# 0.07585818002124356

# %%
# 예시 3: 선형 회귀 결과 (H(x))가 0일 때 시그모이드 값을 계산합니다.

sigmoid_0 = 1 / (1 + e**-(0))

sigmoid_0
# Out:
# 0.5

# %%
# 예시 4: 선형 회귀 결과 (H(x))가 2.5일 때 시그모이드 값을 계산합니다.

sigmoid_2_5 = 1 / (1 + e**-(2.5))

sigmoid_2_5
# Out:
# 0.9241418199787566

# %%
# 예시 5: 선형 회귀 결과 (H(x))가 5일 때 시그모이드 값을 계산합니다.

sigmoid_5 = 1 / (1 + e**-(5))

sigmoid_5
# Out:
# 0.9933071490757153

# %%
from math import e

# %%
# 자연상수 e의 값을 출력하여 확인합니다.
e
# Out:
# 2.718281828459045

# %%
# e를 거듭제곱하여 -1승(역수)을 계산합니다.
e**-1
# Out:
# 0.36787944117144233

# %%
# e를 거듭제곱하여 -0승을 계산합니다.
e**0
# Out:
# 1.0
